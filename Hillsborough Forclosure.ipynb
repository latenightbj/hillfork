# %%
import pandas as pd

df =  pd.read_csv('data/sept20todec2021.csv')

df
# Out:
#       Sale Date    Add Date           Case Number           Status  \
# 0    09/20/2021  06/14/2021  292018CA005366A001HC  Accepting Proxy
# 1    09/20/2021  07/23/2021  292019CA013040A001HC  Accepting Proxy
# 2    09/20/2021  08/16/2021  292018CA010101A001HC  Accepting Proxy
# 3    09/20/2021  09/01/2021  292020CA009864A001HC  Accepting Proxy
# 4    09/21/2021  07/21/2021  292014CA001244A001HC  Accepting Proxy
# ..          ...         ...                   ...              ...
# 139  11/24/2021  07/27/2021  292020CA002259A001HC  Accepting Proxy
# 140  11/24/2021  09/01/2021  292020CA009314A001HC  Accepting Proxy
# 141  12/02/2021  08/24/2021  292020CA002247A001HC  Accepting Proxy
# 142  12/07/2021  08/11/2021  292018CA003822A001HC  Accepting Proxy
# 143  12/09/2021  07/14/2021  292018CA009441A001HC  Accepting Proxy
#
#      Final Judgment  Opening Bid  Assessed Value  \
# 0         128356.39            0          133261
# 1         151815.40            0           84434
# ...

# %%
to_drop = ['Status', 
          'Opening Bid',
           'Primary Plaintiff',
           'Certificate Holder Name',
           'Plaintiff Max Bid',
          'My Bid',
          ]

# %%
df.drop(columns=to_drop, inplace=True)

# %%
df
# Out:
#       Sale Date    Add Date           Case Number  Final Judgment  \
# 0    09/20/2021  06/14/2021  292018CA005366A001HC       128356.39
# 1    09/20/2021  07/23/2021  292019CA013040A001HC       151815.40
# 2    09/20/2021  08/16/2021  292018CA010101A001HC       253987.70
# 3    09/20/2021  09/01/2021  292020CA009864A001HC       180560.79
# 4    09/21/2021  07/21/2021  292014CA001244A001HC       399041.46
# ..          ...         ...                   ...             ...
# 139  11/24/2021  07/27/2021  292020CA002259A001HC            0.00
# 140  11/24/2021  09/01/2021  292020CA009314A001HC            0.00
# 141  12/02/2021  08/24/2021  292020CA002247A001HC            0.00
# 142  12/07/2021  08/11/2021  292018CA003822A001HC            0.00
# 143  12/09/2021  07/14/2021  292018CA009441A001HC            0.00
#
#      Assessed Value                Address        City      Zip  \
# 0            133261       1601 N ORANGE ST  PLANT CITY  33563.0
# ...
